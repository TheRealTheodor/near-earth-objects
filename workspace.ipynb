# %% [markdown]
# Questions for NEO.csv dataset

# %%
import csv

with open("data/neos.csv","r") as infile:
    reader=csv.reader(infile)
    n=-1
    for row in reader:
        n+=1
    print(n)
# Out:
# 23967

# %%
import csv

with open("data/neos.csv","r") as infile:
    reader=csv.reader(infile)
    print(next(reader))
    print(next(reader))
# Out:
# ['id', 'spkid', 'full_name', 'pdes', 'name', 'prefix', 'neo', 'pha', 'H', 'G', 'M1', 'M2', 'K1', 'K2', 'PC', 'diameter', 'extent', 'albedo', 'rot_per', 'GM', 'BV', 'UB', 'IR', 'spec_B', 'spec_T', 'H_sigma', 'diameter_sigma', 'orbit_id', 'epoch', 'epoch_mjd', 'epoch_cal', 'equinox', 'e', 'a', 'q', 'i', 'om', 'w', 'ma', 'ad', 'n', 'tp', 'tp_cal', 'per', 'per_y', 'moid', 'moid_ld', 'moid_jup', 't_jup', 'sigma_e', 'sigma_a', 'sigma_q', 'sigma_i', 'sigma_om', 'sigma_w', 'sigma_ma', 'sigma_ad', 'sigma_n', 'sigma_tp', 'sigma_per', 'class', 'producer', 'data_arc', 'first_obs', 'last_obs', 'n_obs_used', 'n_del_obs_used', 'n_dop_obs_used', 'condition_code', 'rms', 'two_body', 'A1', 'A2', 'A3', 'DT']
# ...

# %%
import csv

with open("data/neos.csv","r") as infile:
    reader=csv.reader(infile)
    for row in reader:
        if row[4] == "Apollo":
            print(row[15])
# Out:
# 1.5

# %%
import csv

with open("data/neos.csv","r") as infile:
    reader=csv.reader(infile)
    n=-1
    for row in reader:
        if row[4] != "":
            n+=1
    print(n)
# Out:
# 343

# %%
import csv

with open("data/neos.csv","r") as infile:
    reader=csv.reader(infile)
    n=-1
    for row in reader:
        if row[15] != "":
            n+=1
    print(n)
# Out:
# 1268

# %%
import json

with open("data/cad.json","r") as infile:
    json_content=json.load(infile)
json_content
# Out:
# Exception ignored in: <bound method IPythonKernel._clean_thread_parent_frames of <ipykernel.ipkernel.IPythonKernel object at 0x7fbffaefbc70>>
# Traceback (most recent call last):
#   File "/home/matej_dvoracek/.cache/pypoetry/virtualenvs/near-earth-objects-6FdNilhm-py3.10/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 775, in _clean_thread_parent_frames
#     def _clean_thread_parent_frames(
# KeyboardInterrupt:
# {'signature': {'source': 'NASA/JPL SBDB Close Approach Data API',
#   'version': '1.1'},
#  'count': '406785',
#  'fields': ['des',
#   'orbit_id',
#   'jd',
#   'cd',
#   'dist',
#   'dist_min',
#   'dist_max',
#   'v_rel',
#   'v_inf',
#   't_sigma_f',
#   'h'],
#  'data': [['170903',
#    '105',
#    '2415020.507669610',
#    '1900-Jan-01 00:11',
#    '0.0921795123769547',
#    '0.0912006569517418',
#    '0.0931589328621254',
#    '16.7523040362574',
#    '16.7505784933163',
#    '01:00',
#    '18.1'],
#   ['2005 OE3',
#    '52',
#    '2415020.606013490',
# ...

# %%
import json

with open("data/cad.json","r") as infile:
    json_content=json.load(infile)
print(len(json_content["data"]))
# Out:
# 406785

# %%
import json

with open("data/cad.json","r") as infile:
    json_content=json.load(infile)
for data in json_content["data"]:
    if "2000-Jan-01" in data[3] and '2015 CL' in data[0]:
        print(data[4])
# Out:
# 0.144929602021186

# %%
import json
import pandas as pd

with open("data/cad.json","r") as infile:
    json_content=json.load(infile)

df=pd.DataFrame(columns=json_content["fields"],data=json_content["data"])
df.head(100000)
# Out:
#               des orbit_id                 jd                 cd  \
# 0          170903      105  2415020.507669610  1900-Jan-01 00:11
# 1        2005 OE3       52  2415020.606013490  1900-Jan-01 02:33
# 2        2006 XO4       15  2415020.634068074  1900-Jan-01 03:13
# 3            7088      233  2415020.709345747  1900-Jan-01 05:01
# 4       2017 EE23        6  2415020.802629888  1900-Jan-01 07:16
# ...           ...      ...                ...                ...
# 99995    2018 CS1        2  2436539.607326917  1958-Dec-02 02:35
# 99996  2006 UL185       22  2436539.681055977  1958-Dec-02 04:21
# 99997   2017 RO17        2  2436539.728698979  1958-Dec-02 05:29
# 99998      471984       33  2436539.810002042  1958-Dec-02 07:26
# 99999   2014 MZ17       15  2436539.872202093  1958-Dec-02 08:56
#
#                      dist            dist_min            dist_max  \
# 0      0.0921795123769547  0.0912006569517418  0.0931589328621254
# ...

# %%
import json

with open("data/cad.json","r") as infile:
    json_content=json.load(infile)
for data in json_content["data"]:
    if "2000-Jan-01" in data[3] and '2002 PB' in data[0]:
        print(data[7])
# Out:
# 29.3862908945476

# %% [markdown]
# Try to rewrite cad.json since it is not properly formatted

# %%
import json

with open("data/cad.json","r") as infile:
    contents= json.load(infile)

with open("data/cad_rew.json","w") as outfile:
    json.dump(contents,outfile, indent=1)

# %%
from extract import load_neos

neos=load_neos()
neos
# Out:
# [NearEarthObject(designation=433, name=433 (Eros), diameter=16.84, hazardous=is not),
#  NearEarthObject(designation=719, name=719 (Albert), diameter=?, hazardous=is not),
#  NearEarthObject(designation=887, name=887 (Alinda), diameter=4.2, hazardous=is not),
#  NearEarthObject(designation=1036, name=1036 (Ganymed), diameter=37.675, hazardous=is not),
#  NearEarthObject(designation=1221, name=1221 (Amor), diameter=1.0, hazardous=is not),
#  NearEarthObject(designation=1566, name=1566 (Icarus), diameter=1.0, hazardous=is),
#  NearEarthObject(designation=1580, name=1580 (Betulia), diameter=5.8, hazardous=is not),
#  NearEarthObject(designation=1620, name=1620 (Geographos), diameter=2.56, hazardous=is),
#  NearEarthObject(designation=1627, name=1627 (Ivar), diameter=9.12, hazardous=is not),
#  NearEarthObject(designation=1685, name=1685 (Toro), diameter=3.4, hazardous=is not),
#  NearEarthObject(designation=1862, name=1862 (Apollo), diameter=1.5, hazardous=is),
# ...

# %%
from extract import load_approaches

appr=load_approaches()

appr
